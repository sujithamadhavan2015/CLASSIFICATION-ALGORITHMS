# %% [markdown]
# # IMPORT NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # DATA ON BOARD

# %%
from google.colab import files
a=files.upload()
# Out:
#      <input type="file" id="files-35a4e519-67a5-4e0d-afb0-d2ff162e2c19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35a4e519-67a5-4e0d-afb0-d2ff162e2c19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # DESCRIPTIVE ANALYSIS
# # DATA PREPROCESSING/EDA

# %%
df=pd.read_csv('svm classifier.csv')

# %%
df.tail()
# Out:
#      gender married   ch  income  loanamt status
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N

# %%
df.head()
# Out:
#   gender married   ch  income  loanamt status
# 0   Male      No  1.0    5849      NaN      Y
# 1   Male     Yes  1.0    4583    128.0      N
# 2   Male     Yes  1.0    3000     66.0      Y
# 3   Male     Yes  1.0    2583    120.0      Y
# 4   Male      No  1.0    6000    141.0      Y

# %%
df.columns
# Out:
# Index(['gender', 'married', 'ch', 'income', 'loanamt', 'status'], dtype='object')

# %%
df.shape
# Out:
# (614, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   601 non-null    object
#  1   married  611 non-null    object
#  2   ch       564 non-null    float64
#  3   income   614 non-null    int64
#  4   loanamt  592 non-null    float64
#  5   status   614 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 28.9+ KB

# %%
df.describe()
# Out:
#                ch        income     loanamt
# count  564.000000    614.000000  592.000000
# mean     0.842199   5403.459283  146.412162
# std      0.364878   6109.041673   85.587325
# min      0.000000    150.000000    9.000000
# 25%      1.000000   2877.500000  100.000000
# 50%      1.000000   3812.500000  128.000000
# 75%      1.000000   5795.000000  168.000000
# max      1.000000  81000.000000  700.000000

# %% [markdown]
# # NULL VALUE DEDUCTION

# %%
df.isnull().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
df1 = df.copy()

# %% [markdown]
# # DROPPING LESS IMPORTANT FEATURES

# %%
df = df.drop(['ch'],axis=1)

# %%
df
# Out:
#      gender married  income  loanamt status
# 0      Male      No    5849      NaN      Y
# 1      Male     Yes    4583    128.0      N
# 2      Male     Yes    3000     66.0      Y
# 3      Male     Yes    2583    120.0      Y
# 4      Male      No    6000    141.0      Y
# ..      ...     ...     ...      ...    ...
# 609  Female      No    2900     71.0      Y
# 610    Male     Yes    4106     40.0      Y
# 611    Male     Yes    8072    253.0      Y
# 612    Male     Yes    7583    187.0      Y
# 613  Female      No    4583    133.0      N
#
# [614 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   601 non-null    object
#  1   married  611 non-null    object
#  2   income   614 non-null    int64
#  3   loanamt  592 non-null    float64
#  4   status   614 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 24.1+ KB

# %% [markdown]
# # FILL NAN VALUES OF THE PARTICULAR DATASET

# %%
num = ['loanamt']

# %%
df[num] = df[num].fillna(df[num].mean())

# %%
df.isnull().sum()
# Out:
# gender     13
# married     3
# income      0
# loanamt     0
# status      0
# dtype: int64

# %%
categorical = ['gender','married']

# %%
df[categorical] = df[categorical].fillna(df.mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# gender     0
# married    0
# income     0
# loanamt    0
# status     0
# dtype: int64

# %%
cleaned_data = df.copy()

# %% [markdown]
# # LABEL ENCODING FOR THE CATEGORICAL FEATURES

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['newgender'] = lb.fit_transform(df['gender'])

# %%
df['t_married'] = lb.fit_transform(df['married'])

# %%
df['newstatus'] = lb.fit_transform(df['status'])

# %%
df
# Out:
#      gender married  income     loanamt status  newgender  t_married  \
# 0      Male      No    5849  146.412162      Y          1          0
# 1      Male     Yes    4583  128.000000      N          1          1
# 2      Male     Yes    3000   66.000000      Y          1          1
# 3      Male     Yes    2583  120.000000      Y          1          1
# 4      Male      No    6000  141.000000      Y          1          0
# ..      ...     ...     ...         ...    ...        ...        ...
# 609  Female      No    2900   71.000000      Y          0          0
# 610    Male     Yes    4106   40.000000      Y          1          1
# 611    Male     Yes    8072  253.000000      Y          1          1
# 612    Male     Yes    7583  187.000000      Y          1          1
# 613  Female      No    4583  133.000000      N          0          0
#
#      newstatus
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# ..         ...
# 609          1
# ...

# %%
df.drop('gender',axis=1,inplace=True)

# %%
df.drop('married',axis=1,inplace=True)

# %%
df.drop('status',axis=1,inplace=True)

# %%
df
# Out:
#      income     loanamt  newgender  t_married  newstatus
# 0      5849  146.412162          1          0          1
# 1      4583  128.000000          1          1          0
# 2      3000   66.000000          1          1          1
# 3      2583  120.000000          1          1          1
# 4      6000  141.000000          1          0          1
# ..      ...         ...        ...        ...        ...
# 609    2900   71.000000          0          0          1
# 610    4106   40.000000          1          1          1
# 611    8072  253.000000          1          1          1
# 612    7583  187.000000          1          1          1
# 613    4583  133.000000          0          0          0
#
# [614 rows x 5 columns]

# %% [markdown]
# # X AND Y SPLIT

# %%
x= df.iloc[:,0:4]
y = df.iloc[:,-1]

# %% [markdown]
# # ACCORDING TO THE PARADO LOGIC WE HAVE TO SPLIT X AND Y AS
# # 80 - 20
# # 70 - 30
# # 75 - 25 (MAXIMUM SPLIT)
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %% [markdown]
# # USING SUPERVISED MODEL LOGISTICAL REGRESSION TO TRAIN A ML MODEL

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state=0)

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_predict = log_reg.predict(x_test)

# %% [markdown]
# # EVALUATION METRICS FOR THE SUPERVISED LOGISTICAL REGRESSION MODEL

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score

# %%
cmlog_reg =  confusion_matrix(y_test,y_predict)
recall = recall_score(y_test,y_predict)
accuracy = accuracy_score(y_test,y_predict)
precision = precision_score(y_test,y_predict)
f1score = f1_score(y_test,y_predict)

# %%
print('CONFUSION METRICS   ','\n',cmlog_reg)
print()
print(' RECALLSCORE   = ',recall)
print('ACCURACYSCORE  = ',accuracy)
print('PRECISIONSCORE = ',precision)
print('    F1SCORE    = ',f1score)
# Out:
# CONFUSION METRICS
#  [[  0  71]
#  [  0 114]]
#
#  RECALLSCORE   =  1.0
# ACCURACYSCORE  =  0.6162162162162163
# PRECISIONSCORE =  0.6162162162162163
#     F1SCORE    =  0.7625418060200669

# %%
df1 = df.copy()

# %%
cleaneddata = df1.copy()

# %%
x= df1.iloc[:,0:4]
y = df1.iloc[:,-1]

# %% [markdown]
# # WITH THE HELP OF BASE LEANER KNN CLASSIFIER ALGORITHM TO TRAIN A ML MODEL

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %% [markdown]
# # Evaluation metrics

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score

# %%
cmknn = confusion_matrix(y_test,y_predict)
recall = recall_score(y_test,y_predict)
accuracy = accuracy_score(y_test,y_predict)
precision = precision_score(y_test,y_predict)
f1score = f1_score(y_test,y_predict)
print('CONFUSIONMETRICS  ','\n',cmknn)
print()
print(' RECALLSCORE   = ',recall)
print('ACCURACYSCORE  = ',accuracy)
print('PRECISIONSCORE = ',precision)
print('   F1SCORE     = ',f1score)
# Out:
# CONFUSIONMETRICS
#  [[11 60]
#  [16 98]]
#
#  RECALLSCORE   =  0.8596491228070176
# ACCURACYSCORE  =  0.5891891891891892
# PRECISIONSCORE =  0.620253164556962
#    F1SCORE     =  0.7205882352941176

# %% [markdown]
# #  WITH THE HELP OF SVM CLASSFIER ALGORITHM GOING EVALUATE THE METRICS

# %%
df2 = cleaneddata.copy()

# %%
x= df2.iloc[:,0:4]
y = df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
ypredict = svm.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score
cmsvm = confusion_matrix(y_test,ypredict)
recall = recall_score(y_test,ypredict)
accuracy=accuracy_score(y_test,ypredict)
precision = precision_score(y_test,ypredict)
f1score = f1_score(y_test,ypredict)
print('CONFUSION METRICS','\n',cmsvm)
print()
print('RECALLSCORE    = ',recall)
print('ACCURACYSCORE  = ',accuracy)
print('PRECISIONSCORE = ',precision)
print('    F1SCORE    = ',f1score)
# Out:
# CONFUSION METRICS
#  [[  0  71]
#  [  0 114]]
#
# RECALLSCORE    =  1.0
# ACCURACYSCORE  =  0.6162162162162163
# PRECISIONSCORE =  0.6162162162162163
#     F1SCORE    =  0.7625418060200669

# %% [markdown]
# # A ML Model is learning better in SVM and LOGISTICAL REGRESSION algorithm better than KNN algorithm.so,i recommend according to the ACCURACYSCORE either in SVM or LOGISTICAL REGRESSION algorithm we will build a model to predict the loanstatus(y variable).
